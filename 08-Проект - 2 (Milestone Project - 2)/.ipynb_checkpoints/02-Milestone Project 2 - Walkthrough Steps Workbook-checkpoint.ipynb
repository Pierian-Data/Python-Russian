# %% [markdown]
# # Домашнее задание - проект 2 - шаги по решению задания
# Ниже приведены шаги, которые можно использовать как путеводитель для создания игры Блэкджек!

# %% [markdown]
# ##  Последовательность игры
# Чтобы сыграть в Блэкджек, следует выполнить следующие шаги:
# 1. Создать колоду из 52 карт
# 2. Перемешать колоду
# 3. Спросить у Игрока его ставку
# 4. Убедиться, что ставка Игрока не превышает количество доступных у него фишек
# 5. Сдать две карты Дилеру и две карты Игроку
# 6. Показать только одну карту из двух карт Дилера, вторая карта остается скрытой
# 7. Показать обе карты Игрока
# 8. Спросить Игрока, хочет ли он взять ещё одну карту (Hit), и если да, то дать ему ещё одну карту
# 9. Если сумма карт игрока не превышает 21, то спросить его, хочет ли он снова взять ещё одну карту.
# 10. Если Игрок говорит "хватит" (т.е., дополнительных карт не нужно), то перейти к картам Дилера. Дилер всегда берёт дополнительные карты до тех пор, пока сумма его карт не станет больше или равна 17
# 11. Определить победителя, и сохранить новое значение для количества фишек у Игрока
# 12. Спросить Игрока, хочет ли он сыграть снова

# %% [markdown]
# ## Игральные карты
# Стандартная колода карт имеет четыре масти - червы (черви, сердце, Hearts), бубны (буби, бубни, ромби, Diamonds), пики (вини, Spades), трефы (крести, кресты, Clubs),  и тринадцать достоинств в каждой масти (от 2 до 10, затем Валет, Дама, Король и Туз). Всего в колоде 52 карты. Валет, Дама и Король имеют каждый 10 очков. Туз имеет либо 11 очков, либо 1 очко таким образом, чтобы получить значение 21 без превышения этого значения. В качестве начальной точки Вашей программы, Вы можете создать переменные для хранения списка мастей, достоинств карт, и затем использовать словарь для хранения соответствия достоинств карт и их значений.

# %% [markdown]
# ## Игра
# ### Команды Imports и глобальные переменные
# ** Шаг 1: импортируйте модуль random. Это нужно для перемешивания колоды карт перед раздачей. Затем объявите переменные для хранения мастей, достоинств и значений. Вы можете разработать свою систему хранения этой информации, или скопировать предложенную ниже. И наконец, объявите переменную Boolean для использования в цикле <code>while</code>. Это обычная практика для контроля хода игры.**
#
#     suits = ('Червы', 'Бубны', 'Пики', 'Трефы')
#     ranks = ('Двойка', 'Тройка', 'Четвёрка', 'Пятерка', 'Шестёрка', 'Семёрка', 'Восьмёрка', 'Девятка', 'Десятка', 'Валет', 'Дама', 'Король', 'Туз')
#     values = {'Двойка':2, 'Тройка':3, 'Четвёрка':4, 'Пятерка':5, 'Шестёрка':6, 'Семёрка':7, 'Восьмёрка':8, 'Девятка':9, 'Десятка':10, 'Валет':10, 'Дама':10, 'Король':10, 'Туз':11}

# %%
import random

suits = pass
ranks = pass
values = pass

playing = True

# %% [markdown]
# ### Определения классов
# Рассмотрите вариант создать класс карты - Card, в котором каждый объект Card имеет масть (suit) и достоинство (rank), и затем класс Deck (колода) для хранения всех 52х объектов Card. Далее перемешайте карты, и наконец можно создать класс Hand (рука) для хранения набора карт, которые достались каждому участнику (игрок и дилер) из колоды.

# %% [markdown]
# **Шаг 2: создайте класс Card**<br>
# Объект Card object будет содержать только два атрибута: масть и достоинство. Также можно добавить атрибут значение - "value" - для хранения количества очков. Мы выбрали вариант хранить это значение позже, в классе Hand.<br>В дополнение к методу \_\_init\_\_ внутри Card, Вы также можете добавить метод \_\_str\_\_, который при необходимости вывести на экран информацию о карте, напечатает например "Двойка Червей"

# %%
class Card:
    
    def __init__(self):
        pass
    
    def __str__(self):
        pass

# %% [markdown]
# **Шаг 3: Создайте класс Deck**<br>
# Здесь мы можем сохранить 52 объекта card в списке, который затем можно перемешать. Но сначала нам нужно *инициализировать* все 52 уникальные карты, и добавить их в наш список. Как только у нас доступен класс Card, мы можем создать объекты Card внутри метода  \_\_init\_\_ для Deck. Сделайте итерации по спискам мастей и достоинств, чтобы создать каждую карту. Это можно сделать внутри класса Deck в методе \_\_init\_\_:
#
#     for suit in suits:
#         for rank in ranks:
#
# В дополнение к методу \_\_init\_\_, мы можем добавить методы для перемешивания нашей колоды карт, а также для выдачи карт во время игры.<br><br>
# ОПЦИОНАЛЬНО: Во время игры Вам не понадобится отображать содержимое колоды карт, однако просмотр карт внутри колоды может пригодиться для отладки программы во время разработки. Для этой цели можно добавить метод \_\_str\_\_ в определение класса.

# %%
class Deck:
    
    def __init__(self):
        self.deck = []  # начинаем с пустого списка
        for suit in suits:
            for rank in ranks:
                pass
    
    def __str__(self):
        pass

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        pass

# %% [markdown]
# ТЕСТИРОВАНИЕ: чтобы проверить, что всё работает, давайте посмотрим на содержимое колоды карт Deck!

# %%
test_deck = Deck()
print(test_deck)

# %% [markdown]
# Отлично! Теперь давайте перейдём к классу Hand.

# %% [markdown]
# **Шаг 4: Создайте класс Hand**<br>
# В дополнение к хранению карт, которые были получены из колоды, класс Hand можно использовать для вычисления значений этих карт, используя упомянутый ранее словарь. Также Вам нужно скорректировать значения для Тузов при необходимости.

# %%
class Hand:
    def __init__(self):
        self.cards = []  # начинаем с пустого списка, так же, как и в классе Deck 
        self.value = 0   # начинаем со значения 0
        self.aces = 0    # добавляем атрибут, чтобы учитывать тузы
    
    def add_card(self,card):
        pass
    
    def adjust_for_ace(self):
        pass

# %% [markdown]
# **Шаг 5: создайте класс Chips (фишки)**<br>
# Также нам нужно хранить начальные фишки Игрока, его ставки и текущие выигрыши. Это можно сделать с помощью глобальных переменных, но чтобы следовать духу объектно-ориентированного программирования, давайте для этой цели создадим класс Chips!

# %%
class Chips:
    
    def __init__(self):
        self.total = 100  # можно установить значение по умолчанию, или запрашивать значение у пользователя
        self.bet = 0
        
    def win_bet(self):
        pass
    
    def lose_bet(self):
        pass

# %% [markdown]
# ### Определения функций
# Многие из шагов будут повторяться. И здесь понадобятся функции! Шаги ниже являются приблизительными - добавляйте и удаляйте функции в Вашей программе по мере необходимости.

# %% [markdown]
# **Шаг 6: Пишем функцию, в которой игрок делает ставки**<br>
# Поскольку мы будем просить пользователя ввести целое число, здесь будет уместно использовать <code>try</code>/<code>except</code>. Не забудьте проверить, что ставка Игрока не превышает количество имеющихся у него фишек.

# %%
def take_bet():
    
    pass

# %% [markdown]
# **Шаг 7: Пишем функцию, в которой Игрок берёт дополнительные карты**<br>
# Любой из Игроков может брать дополнительные карты до тех пор, пока не превысит 21. Эта функция будет вызываться в игре каждый раз, когда Игрок запрашивает дополнительную карту, или когда у Дилера меньше 17 очков. В этой функции можно использовать объекты Deck и Hand в качестве параметров, выдавать одну карту из колоды и добавлять её в объект Hand. Вы также можете проверить наличие Тузов в случае, если сумма карт игрока превышает 21.

# %%
def hit(deck,hand):
    
    pass

# %% [markdown]
# **Шаг 8: Напишите функцию, которая предлагает Игроку взять дополнительную карту или остаться при текущих картах**<br>
# Эта функция может принимать колоду и карты игрока hand в качестве параметров, и присваивать значения глобальной переменной playing.<br>
# Если Игрок запрашивает дополнительную карту, то вызываем функцию hit(), которую мы обсуждали выше. Если Игрок остается при своих картах, то устанавливаем переменную playing в значение False - с помощью этой переменной мы будем контролировать цикл <code>while</code> позже.

# %%
def hit_or_stand(deck,hand):
    global playing  # для контроля цикла while
    
    pass

# %% [markdown]
# **Шаг 9: Пишем функции для отображения карт**<br>
# В начале игры, и всякий раз когда Игрок берёт дополнительную карту, первая карта Дилера скрыта, а все карты Игрока видны. В конце игры показываются все карты, и Вы можете показать количество очков для каждого из участников. Напишите функции для каждого из этих сценариев.

# %%
def show_some(player,dealer):
    
    pass
    
def show_all(player,dealer):
    
    pass

# %% [markdown]
# **Шаг 10: Напишите функции для обработки сценариев завершения игры**<br>
# В качестве параметров по мере необходимости передавайте объекты hand Игрока, hand Дилера и chips.

# %%
def player_busts():
    pass

def player_wins():
    pass

def dealer_busts():
    pass
    
def dealer_wins():
    pass
    
def push():
    pass

# %% [markdown]
# ### И теперь сама игра!!

# %%
while True:
    # Напишите приветственное сообщение

    
    # Создайте и перемешайте колоду карт, выдайте каждому Игроку по две карты

    
        
    # Установите количество фишек Игрока
    
    
    # Спросите у Игрока его ставку

    
    # Покажите карты (но оставьте одну и карт Дилера скрытой)

    
    while playing:  # помните, это переменная из нашей функции hit_or_stand 
        
        # Спросите Игрока, хочет ли он взять дополнительную карту или остаться при текущих картах
        
        
        # Покажите карты (но оставьте одну и карт Дилера скрытой)
 
        
        # Если карты Игрока превысили 21, запустите player_busts() и выйдите из цикла (break)
        

            break

    # Если карты Игрока не превысили 21, перейдите к картам Дилера и берите доп. карты до суммы карт >=17
    
        # Показываем все карты
    
        # Выполняем различные варианты завершения игры
        
    
    # Сообщить Игроку сумму его фишек 
    
    # Спросить его, хочет ли он сыграть снова

        break

# %% [markdown]
# Вот и всё! Помните, что эти шаги могут существенно отличаться от Вашего решения. Это вполне нормально! Работайте над различными частями программы до тех пор, пока не получите нужный результат. Для этого нужно много времени и терпения! Как всегда, Вы можете задавать вопросы и оставлять комментарии в форуме Q&A.
# # Отличная работа!
